# %% [markdown]
# ## CV2 Read batch
#
# This notebook is used to detect faces from pictures in batch. It consists of three functions:
# - Detect faces based on haarcascade
# - Detect faces based on opencv deep learning
# - Detect faces combining haarcascade and deep learning
#
# Besides it has two possibilities to process images:
# - Read images from a specific folder, process them and store the processed image in another folder
# - Crawl over a directory structure and make the same structure for processed images

# %%
# import the necessary packages
import os
import numpy as np
import argparse
import cv2
import glob
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Initialize the haarcascade classifier for face detection
cascade_file_src = "haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascade_file_src)

# %%
# Some command line arguments are needed to be able to execute the deep learning model for face detection
args = {
    "prototxt": "deploy.prototxt.txt",
    "model": "res10_300x300_ssd_iter_140000.caffemodel",
    }
# Out:
# {'model': 'res10_300x300_ssd_iter_140000.caffemodel',
#  'prototxt': 'deploy.prototxt.txt'}

# %%
# load the serialized model from disk
print("[INFO] loading model...")
net = cv2.dnn.readNetFromCaffe(args["prototxt"], args["model"])
# Out:
# [INFO] loading model...

# %% [markdown]
# ## Deep learning function

# %%
def ext_faces(image):
    # Determine dimensions of picture
    (h, w) = image.shape[:2]
    # Prepare the image for the network
    blob = cv2.dnn.blobFromImage(cv2.resize(image, (300,300)), 1.0, (300, 300), (104.0, 177.0, 123.0))

    # pass the blob through the network and obtain the detections and
    # predictions
    net.setInput(blob)
    detections = net.forward()
    faces =[]
    # loop over the detections
    for i in range(0, detections.shape[2]):
        # extract the confidence (i.e., probability) associated with the prediction
        confidence = detections[0, 0, i, 2]
        # filter out weak detections by ensuring the `confidence` is greater than the minimum confidence.
        if confidence > 0.9: 
            # compute the (x, y)-coordinates of the bounding box for the
            # object
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            #print(box)
            (startX, startY, endX, endY) = box.astype("int")
            img = cv2.rectangle(image,(startX,startY),(endX,endY),(255,0,0),2)
            img = image[startY:endY, startX:endX]
            face = cv2.resize(img,((224,224)))
            faces.append(face)
    print('number of faces found:', len(faces))
    return(faces)

# %% [markdown]
# ## Haarcascade function

# %%
def ext_faces2(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # detect faces
    # scaleFactor and minNeighbours are set high
    # Clarification properties: http://www.bogotobogo.com/python/OpenCV_Python/python_opencv3_Image_Object_Detection_Face_Detection_Haar_Cascade_Classifiers.php
    faces = faceCascade.detectMultiScale(gray, 1.3, 5)
    print('# faces found:',len(faces))
    facecrop = []
    # crop right area
    for f in faces:
            x, y, w, h = [ v for v in f ]
            facecrop.append(image[y:y+h, x:x+w])
    facecrop2 = []
    # resize to right number of pixels
    for face in facecrop:
        crpim = cv2.resize(face,((224,224)))
        facecrop2.append(crpim)
    return facecrop2

# %% [markdown]
# ## Function that searches faces with haarcascade and confirms with deep learning

# %%
def ext_faces3(image):
    # First haarcascade is used to find faces 
    # Using low values of scaleFactor and minNeighbours (with many false positives)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.2, 3)
    facecrop = []
    # The faces are cropped and the resulting images are fed in a sequence to the neural net.
    for f in faces:
        x, y, w, h = [ v for v in f ]
        facecrop.append(image[y:y+h, x:x+w])
    confirmed = []
    for img in facecrop:    
        blob = cv2.dnn.blobFromImage(cv2.resize(img, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0))
        net.setInput(blob)
        detections = net.forward()
        # Probability function of 0.9 can be changed to filter false positives
        if detections[0, 0, 0, 2] > 0.9:
            face = cv2.resize(img,((224,224)))
            confirmed.append(face)
    print('# faces found:',len(confirmed))
    return(confirmed)

# %% [markdown]
# ## Processing files in one folder

# %%
cv_img = []
names =[]
for img in glob.glob("nofaces/*.jpg"):
    image= cv2.imread(img)
    name = img[8:-4]
    print(name)
    faces = ext_faces3(image)
    for i, face in enumerate(faces):
        cv2.imwrite("output/" + name + "_" + str(i) + ".jpg", face)
# Out:
# 20151003_085614
# # faces found: 0
# 20151003_085629
# # faces found: 0
# 20151003_085633
# # faces found: 0
# 20151003_085641
# # faces found: 0
# 20151003_085643
# # faces found: 0
# 20151003_085648
# # faces found: 0
# 20151003_085723
# # faces found: 0
# 20151003_085725
# # faces found: 0
# 20151003_085734
# # faces found: 0
# 20151003_085827
# # faces found: 0
# 20151003_085948
# # faces found: 0
# 20151003_085950
# # faces found: 0
# IMG-20151003-WA0029
# # faces found: 0

# %% [markdown]
# ## Processing files in multiple folders

# %%
# Iterate over directories and files
# Creates equal directory structure with processed files
# Faces in the wild: http://vis-www.cs.umass.edu/lfw/index.html

rootdir ='lfw/'
newdir = 'output'

for subdir, dirs, files in os.walk(rootdir):
    crdir = newdir + subdir[4:]
    print(crdir)
    os.makedirs(crdir)
    for file in files:
        if file[-4:] == ".jpg":
            filepath = subdir + '/' + file
            #print(filepath)
            image= cv2.imread(filepath)
            name = file[:-4]
            faces = ext_faces3(image)
            for i, face in enumerate(faces):
                wrfile = newdir + subdir[4:] + '/' + name + "_" + str(i) + ".jpg"
                print(wrfile)
                cv2.imwrite(wrfile, face)
# Out:
# output6/
# output6/.ipynb_checkpoints
# output6/Bill_Simon
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0001_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0002_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0003_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0004_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0005_0.jpg
# # faces found: 0
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0007_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0008_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0009_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0010_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0011_0.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0012_0.jpg
# # faces found: 2
# output6/Bill_Simon/Bill_Simon_0013_0.jpg
# output6/Bill_Simon/Bill_Simon_0013_1.jpg
# # faces found: 1
# output6/Bill_Simon/Bill_Simon_0014_0.jpg
# # faces found: 2
# output6/Bill_Simon/Bill_Simon_0015_0.jpg
# output6/Bill_Simon/Bill_Simon_0015_1.jpg
# output6/Britney_Spears
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0001_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0002_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0003_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0004_0.jpg
# # faces found: 2
# output6/Britney_Spears/Britney_Spears_0005_0.jpg
# output6/Britney_Spears/Britney_Spears_0005_1.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0006_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0007_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0008_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0009_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0010_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0011_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0012_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0013_0.jpg
# # faces found: 1
# output6/Britney_Spears/Britney_Spears_0014_0.jpg
# output6/Dick_Cheney
# # faces found: 2
# output6/Dick_Cheney/Dick_Cheney_0001_0.jpg
# output6/Dick_Cheney/Dick_Cheney_0001_1.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0002_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0003_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0004_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0005_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0006_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0007_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0008_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0009_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0010_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0011_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0012_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0013_0.jpg
# # faces found: 1
# output6/Dick_Cheney/Dick_Cheney_0014_0.jpg
# output6/Halle_Berry
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0001_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0002_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0003_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0004_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0005_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0006_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0007_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0008_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0009_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0010_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0011_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0012_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0013_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0014_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0015_0.jpg
# # faces found: 1
# output6/Halle_Berry/Halle_Berry_0016_0.jpg
# output6/Harrison_Ford
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0001_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0002_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0003_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0004_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0005_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0006_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0007_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0008_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0009_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0010_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0011_0.jpg
# # faces found: 1
# output6/Harrison_Ford/Harrison_Ford_0012_0.jpg
# output6/Howard_Dean
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0001_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0002_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0003_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0004_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0005_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0006_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0007_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0008_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0009_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0010_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0011_0.jpg
# # faces found: 1
# output6/Howard_Dean/Howard_Dean_0012_0.jpg
# output6/Jeb_Bush
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0001_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0002_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0003_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0004_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0005_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0006_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0007_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0008_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0009_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0010_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0011_0.jpg
# # faces found: 1
# output6/Jeb_Bush/Jeb_Bush_0012_0.jpg
# output6/Jennifer_Garner
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0001_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0002_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0003_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0004_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0005_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0006_0.jpg
# # faces found: 2
# output6/Jennifer_Garner/Jennifer_Garner_0007_0.jpg
# output6/Jennifer_Garner/Jennifer_Garner_0007_1.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0008_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0009_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0010_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0011_0.jpg
# # faces found: 1
# output6/Jennifer_Garner/Jennifer_Garner_0012_0.jpg
# output6/John_Snow
# # faces found: 1
# output6/John_Snow/John_Snow_0001_0.jpg
# # faces found: 0
# # faces found: 1
# output6/John_Snow/John_Snow_0003_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0004_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0005_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0006_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0007_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0008_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0009_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0010_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0011_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0012_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0013_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0014_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0015_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0016_0.jpg
# # faces found: 1
# output6/John_Snow/John_Snow_0017_0.jpg
# output6/Meryl_Streep
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0001_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0002_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0003_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0004_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0005_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0006_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0007_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0008_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0009_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0010_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0011_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0012_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0013_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0014_0.jpg
# # faces found: 1
# output6/Meryl_Streep/Meryl_Streep_0015_0.jpg
# output6/Nancy_Pelosi
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0001_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0002_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0003_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0004_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0005_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0006_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0007_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0008_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0009_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0010_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0011_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0012_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0013_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0014_0.jpg
# # faces found: 1
# output6/Nancy_Pelosi/Nancy_Pelosi_0015_0.jpg
# output6/Naomi_Watts
# # faces found: 2
# output6/Naomi_Watts/Naomi_Watts_0001_0.jpg
# output6/Naomi_Watts/Naomi_Watts_0001_1.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0002_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0003_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0004_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0005_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0006_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0007_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0008_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0009_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0010_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0011_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0012_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0013_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0014_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0015_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0016_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0017_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0018_0.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0019_0.jpg
# # faces found: 2
# output6/Naomi_Watts/Naomi_Watts_0020_0.jpg
# output6/Naomi_Watts/Naomi_Watts_0020_1.jpg
# # faces found: 1
# output6/Naomi_Watts/Naomi_Watts_0021_0.jpg
# # faces found: 2
# output6/Naomi_Watts/Naomi_Watts_0022_0.jpg
# output6/Naomi_Watts/Naomi_Watts_0022_1.jpg
# output6/Nicole_Kidman
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0001_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0002_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0003_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0004_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0005_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0006_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0007_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0008_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0009_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0010_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0011_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0012_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0013_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0014_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0015_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0016_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0017_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0018_0.jpg
# # faces found: 1
# output6/Nicole_Kidman/Nicole_Kidman_0019_0.jpg
# output6/Richard_Gephardt
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0001_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0002_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0003_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0004_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0005_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0006_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0007_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0008_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0009_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0010_0.jpg
# # faces found: 1
# output6/Richard_Gephardt/Richard_Gephardt_0011_0.jpg
# output6/Salma_Hayek
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0001_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0002_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0003_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0004_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0005_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0006_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0007_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0008_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0009_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0010_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0011_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0012_0.jpg
# # faces found: 1
# output6/Salma_Hayek/Salma_Hayek_0013_0.jpg
# output6/Sergey_Lavrov
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0001_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0002_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0003_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0004_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0005_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0006_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0007_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0008_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0009_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0010_0.jpg
# # faces found: 1
# output6/Sergey_Lavrov/Sergey_Lavrov_0011_0.jpg
# output6/Ann_Veneman
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0007_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0008_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0009_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0010_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0011_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0001_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0002_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0003_0.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0005_0.jpg
# # faces found: 2
# output6/Ann_Veneman/Ann_Veneman_0004_0.jpg
# output6/Ann_Veneman/Ann_Veneman_0004_1.jpg
# # faces found: 1
# output6/Ann_Veneman/Ann_Veneman_0006_0.jpg
